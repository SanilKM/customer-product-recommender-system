# %% [markdown]
# # Hybrid Recommender Modeling and Validation
#
# Runs the hybrid recommender and proxy validation stage.

# %%
from pathlib import Path

features_dir = Path('data/02_features')
model_dir = Path('data/03_model_outputs')
script_path = Path('src') / 'recommender_modeling_and_validation.py'

print('Feature input folder:', features_dir.resolve())
print('Model output folder:', model_dir.resolve())
print('Script:', script_path.resolve())

# %%
# !python src/recommender_modeling_and_validation.py --input-dir data/02_features --output-dir data/03_model_outputs

# %%
import pandas as pd
from pathlib import Path

model_dir = Path('data/03_model_outputs')
for file in ['modeling_sanity_checks.csv', 'model_comparison_proxy_metrics.csv', 'recommendation_reason_summary.csv']:
    path = model_dir / file
    print('\n' + file)
    if path.exists():
        display(pd.read_csv(path).head(20))
    else:
        print('Not found yet:', path)
