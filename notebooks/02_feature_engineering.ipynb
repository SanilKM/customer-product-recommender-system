# %% [markdown]
# # Feature Engineering Pipeline
#
# Runs the feature engineering script using the clean project structure.

# %%
from pathlib import Path

raw_dir = Path('data/01_raw')
features_dir = Path('data/02_features')
script_path = Path('src') / 'feature_engineering.py'

print('Raw data folder:', raw_dir.resolve())
print('Feature output folder:', features_dir.resolve())
print('Script:', script_path.resolve())

# %%
# !python src/feature_engineering.py --csv-dir data/01_raw --output-dir data/02_features

# %%
import pandas as pd
from pathlib import Path

features_dir = Path('data/02_features')
checks_path = features_dir / 'pipeline_sanity_checks.csv'
if checks_path.exists():
    display(pd.read_csv(checks_path))
else:
    print('Run the pipeline first to create pipeline_sanity_checks.csv')
